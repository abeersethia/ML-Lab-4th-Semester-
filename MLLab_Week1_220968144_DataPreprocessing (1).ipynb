# %% [markdown]
# ## Week 1: Data Preprocessing
# Abeer Sethia | 220968144

# %% [markdown]
# 1. Find the mean, median, mode, variance, and standard deviation of a list. (import statistics)
# 2. Create a list of numbers and use list comprehension to generate a new list with the squares of each number.
# 3. Write a function that takes a tuple of numbers and returns the product of all the elements.
# 4. Write a program that counts the frequency of each letter in each string and stores the results in a dictionary.

# %% [markdown]
# ### 1.Find the mean, median, mode, variance, and standard deviation of a list. (import statistics)

# %%
import statistics
data = [1, 3, 4, 5, 7, 9, 2]
x = statistics.mean(data)
y=statistics.median(data)
z=statistics.mode(data)
a=statistics.variance(data)
b=statistics.stdev(data)
print("Mean is :", x)
print("Median is :",y)
print("Mode is :",z)
print("Variance is :",a)
print("Standard Deviation is :",b)
# Out:
# Mean is : 4.428571428571429
# Median is : 4
# Mode is : 1
# Variance is : 7.9523809523809526
# Standard Deviation is : 2.819996622760558

# %% [markdown]
# ### 2.Create a list of numbers and use list comprehension to generate a new list with the squares of each number

# %%
data = [1, 3, 4, 5, 7, 9, 2]
newlist = []
for x in data:
    newlist.append(x*x)
print("New List:",newlist)
# Out:
# New List: [1, 9, 16, 25, 49, 81, 4]

# %% [markdown]
# ### 3. Write a function that takes a tuple of numbers and returns the product of all the elements.

# %%
data=(1, 3, 4, 5, 7, 9, 2)
prod=1
for x in data:
    prod=prod*x
print("Product is:", prod)
# Out:
# Product is: 7560

# %% [markdown]
# ### 4. Write a program that counts the frequency of each letter in each string and stores the results in a dictionary.

# %%
string="naman"
letter_count = {}
for char in string:
    if char in letter_count:
        letter_count[char] += 1
    else:
        letter_count[char] = 1
print(letter_count)
# Out:
# {'n': 2, 'a': 2, 'm': 1}

# %% [markdown]
# ### 5. Explore two different datasets provided in the shared folders with the following steps:

# %% [markdown]
# ### Data: Data1.csv
# Explore two different datasets provided in the shared folders with the following steps:
# 1. Import the required libraries.
# 2. Load the dataset.
# 3. Examine data information.
# 4. Identify and analyze null values using df. isnull().
# 5. Conduct statistical analysis. (count, mean, SD, min, max, Quartile)
# 6. Generate boxplots for each column to detect outliers.
# 7. Determine quartiles and remove outliers.
# 8. Calculate correlations and visualize them with a heatmap.
# 9. Normalize the various features of the given datasets. (MinMaxScaler)
# 10. Arrange correlation values for each attribute in ascending order

# %% [markdown]
# ## DATA1

# %%
#a. Import the required libraries.
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

#b. Load the dataset.
df=pd.read_csv("C:\\Users\\NAMAN MAHESHWARI\\OneDrive\\Desktop\\FOURTH SEM\\ML\\LAB\\WEEK1\\Data1.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#c. Examine data information.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#d. Identify and analyze null values using df. isnull().
print(df.isnull().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#e. Conduct statistical analysis. (count, mean, SD, min, max, Quartile)
print(df.describe())
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#f. Generate boxplots for each column to detect outliers.
sns.boxplot(data=df,orient="h")
# Out:
# <Axes: >

# %%
#g. Determine quartiles and remove outliers.
for i in df.columns:
    iqr=df[i].quantile(0.75)-df[i].quantile(0.25)
    max=df[i].quantile(0.75)+(1.5*iqr)
    min=df[i].quantile(0.25)-(1.5*iqr)
    for j in df[i]:
        if(j>max or j<min):
            df[i].replace(j,df[i].median(),inplace=True)
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.782552  121.656250      72.196615      20.437500   60.857259
# std       3.270644   30.438286      11.146723      15.698554   77.660549
# min       0.000000   44.000000      38.000000       0.000000    0.000000
# 25%       1.000000   99.750000      64.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   29.000000
# 75%       6.000000  140.250000      80.000000      32.000000  110.000000
# max      13.000000  199.000000     106.000000      63.000000  318.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.198958                  0.427615   32.760417    0.348958
# std      6.410558                  0.245174   11.055385    0.476951
# ...

# %%
#h. Calculate correlations and visualize them with a heatmap.
correlation_matrix1 = df.corr()
sns.heatmap(correlation_matrix1, annot=True)
# Out:
# <Axes: >

# %%
#i. Normalize the various features of the given datasets. (MinMaxScaler)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(df)
scaler.transform(df)
# Out:
# array([[0.46153846, 0.67096774, 0.5       , ..., 0.49326146, 0.64444444,
#         1.        ],
#        [0.07692308, 0.26451613, 0.41176471, ..., 0.24528302, 0.22222222,
#         0.        ],
#        [0.61538462, 0.89677419, 0.38235294, ..., 0.53369272, 0.24444444,
#         1.        ],
#        ...,
#        [0.38461538, 0.49677419, 0.5       , ..., 0.15004492, 0.2       ,
#         0.        ],
#        [0.07692308, 0.52903226, 0.32352941, ..., 0.24348607, 0.57777778,
#         1.        ],
#        [0.07692308, 0.31612903, 0.47058824, ..., 0.21293801, 0.04444444,
#         0.        ]])

# %%
#j. Arrange correlation values for each attribute in ascending order.
b=pd.DataFrame(df.corr())
for i in b.columns:
    print(b[i].sort_values(ascending=True))
# Out:
# Insulin                    -0.108479
# SkinThickness              -0.096720
# DiabetesPedigreeFunction    0.004554
# BMI                         0.028339
# Glucose                     0.117692
# Outcome                     0.202492
# BloodPressure               0.208953
# Age                         0.560768
# Pregnancies                 1.000000
# Name: Pregnancies, dtype: float64
# SkinThickness               0.060034
# DiabetesPedigreeFunction    0.081515
# Pregnancies                 0.117692
# Insulin                     0.178601
# BloodPressure               0.204539
# BMI                         0.228245
# Age                         0.274264
# Outcome                     0.492782
# Glucose                     1.000000
# Name: Glucose, dtype: float64
# Insulin                    -0.050918
# DiabetesPedigreeFunction    0.022479
# SkinThickness               0.025645
# Outcome                     0.164874
# Glucose                     0.204539
# ...

# %% [markdown]
# ## DATA2

# %%
#a. Import the required libraries.
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

#b. Load the dataset.
df=pd.read_excel("C:\\Users\\NAMAN MAHESHWARI\\OneDrive\\Desktop\\FOURTH SEM\\ML\\LAB\\WEEK1\\Data2.xlsx")
df
# Out:
#     DISTCD          STATNAME            DISTNAME  BLOCKS  VILLAGES  CLUSTERS  \
# 0      101   JAMMU & KASHMIR             KUPWARA      13       391       104
# 1      102   JAMMU & KASHMIR            BARAMULA      18       678       144
# 2      103   JAMMU & KASHMIR            SRINAGAR       8        94        65
# 3      201  HIMACHAL PRADESH              CHAMBA      15      1150       266
# 4      202  HIMACHAL PRADESH              KANGRA      19      1785       358
# 5      203  HIMACHAL PRADESH       LAHUL & SPITI       4       168        53
# 6      309            PUNJAB            LUDHIANA      12      1044       143
# 7      310            PUNJAB                MOGA       5       332        46
# 8      311            PUNJAB            FIROZPUR       6       666        79
# 9      401        CHANDIGARH          CHANDIGARH      20        84        20
# 10     501       UTTARAKHAND          UTTARKASHI       6       662        61
# ...

# %%
#c. Examine data information.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DISTCD      32 non-null     int64
#  1   STATNAME    32 non-null     object
#  2   DISTNAME    32 non-null     object
#  3   BLOCKS      32 non-null     int64
#  4   VILLAGES    32 non-null     int64
#  5   CLUSTERS    32 non-null     int64
#  6   TOTPOPULAT  32 non-null     int64
# dtypes: int64(5), object(2)
# memory usage: 1.9+ KB

# %%
#d. Identify and analyze null values using df. isnull().
print(df.isnull().sum())
# Out:
# DISTCD        0
# STATNAME      0
# DISTNAME      0
# BLOCKS        0
# VILLAGES      0
# CLUSTERS      0
# TOTPOPULAT    0
# dtype: int64

# %%
#e. Conduct statistical analysis. (count, mean, SD, min, max, Quartile)
print(df.describe())
# Out:
#             DISTCD     BLOCKS     VILLAGES   CLUSTERS    TOTPOPULAT
# count    32.000000  32.000000    32.000000   32.00000  3.200000e+01
# mean    615.562500  10.906250   764.062500  126.87500  2.043326e+06
# std     312.572979   6.034093   540.128595  104.32386  1.499800e+06
# min     101.000000   3.000000    80.000000    6.00000  3.152800e+04
# 25%     310.750000   6.000000   318.750000   51.25000  8.814545e+05
# 50%     652.000000   9.000000   664.000000   83.00000  1.643436e+06
# 75%     902.250000  15.250000  1111.750000  175.00000  3.470142e+06
# max    1006.000000  27.000000  1937.000000  378.00000  5.082868e+06

# %%
#f. Generate boxplots for each column to detect outliers.
sns.boxplot(data=df,orient="h")
# Out:
# <Axes: >

# %%
#g. Determine quartiles and remove outliers.
df.drop("STATNAME",axis=1,inplace=True)
df.drop("DISTNAME",axis=1,inplace=True)
for i in df.columns:
    iqr=df[i].quantile(0.75)-df[i].quantile(0.25)
    max=df[i].quantile(0.75)+(1.5*iqr)
    min=df[i].quantile(0.25)-(1.5*iqr)
    for j in df[i]:
        if(j>max or j<min):
            df[i].replace(j,df[i].median(),inplace=True)
df.describe()
# Out:
#             DISTCD     BLOCKS     VILLAGES    CLUSTERS    TOTPOPULAT
# count    32.000000  32.000000    32.000000   32.000000  3.200000e+01
# mean    615.562500  10.906250   764.062500  117.656250  2.043326e+06
# std     312.572979   6.034093   540.128595   93.933611  1.499800e+06
# min     101.000000   3.000000    80.000000    6.000000  3.152800e+04
# 25%     310.750000   6.000000   318.750000   51.250000  8.814545e+05
# 50%     652.000000   9.000000   664.000000   81.500000  1.643436e+06
# 75%     902.250000  15.250000  1111.750000  161.500000  3.470142e+06
# max    1006.000000  27.000000  1937.000000  358.000000  5.082868e+06

# %%
#h. Calculate correlations and visualize them with a heatmap.
import matplotlib.pyplot as mpl
sns.heatmap(df.corr(),annot=True)
mpl.show()

# %%
#i. Normalize the various features of the given datasets. (MinMaxScaler)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(df)
scaler.transform(df)
# Out:
# array([[0.        , 0.41666667, 0.16747442, 0.27840909, 0.1670915 ],
#        [0.00110497, 0.625     , 0.32202477, 0.39204545, 0.19479485],
#        [0.00220994, 0.20833333, 0.00753904, 0.16761364, 0.24512763],
#        [0.11049724, 0.5       , 0.57619817, 0.73863636, 0.09647262],
#        [0.11160221, 0.66666667, 0.91814755, 1.        , 0.29213931],
#        [0.11270718, 0.04166667, 0.04738826, 0.13352273, 0.        ],
#        [0.22983425, 0.375     , 0.51911686, 0.38920455, 0.68424497],
#        [0.23093923, 0.08333333, 0.13570275, 0.11363636, 0.19019923],
#        [0.2320442 , 0.125     , 0.31556274, 0.20738636, 0.39500469],
#        [0.33149171, 0.70833333, 0.00215401, 0.03977273, 0.2025518 ],
#        [0.44198895, 0.125     , 0.31340872, 0.15625   , 0.05902553],
#        [0.44309392, 0.25      , 0.39256866, 0.20454545, 0.07118626],
#        [0.4441989 , 0.        , 0.24609585, 0.11363636, 0.04064842],
#        [0.55248619, 0.04166667, 0.10716209, 0.10511364, 0.10440042],
# ...

# %%
#j. Arrange correlation values for each attribute in ascending order.
b=pd.DataFrame(df.corr())
for i in b.columns:
    print(b[i].sort_values(ascending=True))
# Out:
# CLUSTERS      0.089456
# BLOCKS        0.171932
# VILLAGES      0.295476
# TOTPOPULAT    0.630933
# DISTCD        1.000000
# Name: DISTCD, dtype: float64
# DISTCD        0.171932
# VILLAGES      0.532225
# TOTPOPULAT    0.559050
# CLUSTERS      0.563770
# BLOCKS        1.000000
# Name: BLOCKS, dtype: float64
# DISTCD        0.295476
# TOTPOPULAT    0.490269
# BLOCKS        0.532225
# CLUSTERS      0.674253
# VILLAGES      1.000000
# Name: VILLAGES, dtype: float64
# DISTCD        0.089456
# TOTPOPULAT    0.308218
# BLOCKS        0.563770
# VILLAGES      0.674253
# CLUSTERS      1.000000
# Name: CLUSTERS, dtype: float64
# CLUSTERS      0.308218
# VILLAGES      0.490269
# BLOCKS        0.559050
# DISTCD        0.630933
# TOTPOPULAT    1.000000
# Name: TOTPOPULAT, dtype: float64

# %% [markdown]
# ### 6. Conduct a visual exploration of the given dataset by employing four distinct Python plotting libraries: Matplotlib, Seaborn, Bokeh, and Plotly. Perform the following visualizations:

# %% [markdown]
# ## DATA1

# %%
#a. Scatter plots with coloured points and adjustable sizes using columns (1) col1, col2 and (2) col3, col4 (3) col5, col6.
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv("C:\\Users\\NAMAN MAHESHWARI\\OneDrive\\Desktop\\FOURTH SEM\\ML\\LAB\\WEEK1\\Data1.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.plot.scatter(x='Pregnancies', y='Glucose')
plt.show()
df.plot.scatter(x='BloodPressure', y='SkinThickness')
plt.show()
df.plot.scatter(x='Insulin', y='BMI')
plt.show()

# %%
#b. Line charts for columns (1) col1, col2 (2) col3, col4 (3) col5, col6.
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.lineplot(data=df, x='Pregnancies', y='Glucose')
plt.show()
sns.lineplot(data=df, x='BloodPressure', y='SkinThickness')
plt.show()
sns.lineplot(data=df, x='Insulin', y='BMI')
plt.show()

# %%
#c. Bar charts representing columns (1) col1, col2 (2) col3, col4 (3) col5, col6.
plt.bar(df.iloc[:,0],df.iloc[:,1])
plt.show()
plt.figure(figsize=(15,10))
plt.bar(df.iloc[:,2],df.iloc[:,3])
plt.xticks(rotation=90)
plt.show()
plt.figure(figsize=(20,10))
plt.bar(df.iloc[:,4],df.iloc[:,5])
plt.xticks(rotation=90)
plt.show()

# %%
#d. Histograms to depict the dataset's distribution.
sns.histplot(df)
plt.show()

# %%
#e. Employ Bokeh for interactive data visualization.
from bokeh.plotting import figure,show
from bokeh.io import output_notebook
fig=figure(x_axis_label="Pregnancies",y_axis_label="Insulin")
fig.vbar(x=df.Pregnancies,top=df.Insulin,width=0.8)
output_notebook()
show(fig)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d858e0b6-f139-41da-bc03-e17037eea2cd">Loading BokehJS ...</span>
#     </div>
#   <div id="edb2b10e-62c4-4ba5-ab24-a77631acb5e2" data-root-id="p1209" style="display: contents;"></div>

# %%
#f. Utilize Bokeh's GUI features, including buttons, sliders, checkboxes, and radio buttons.
from bokeh.models import Button,CheckboxGroup, RadioGroup, Slider
from bokeh.plotting import show

button = Button(label="Button")
show(button)
# Out:
#   <div id="cff5f7d4-9601-48c4-8229-4f3e8f08418c" data-root-id="p1248" style="display: contents;"></div>

# %%
slider = Slider(start=0, end=10, value=5, step=1, title="Slider")
show(slider)
# Out:
#   <div id="d552b815-3fd4-470c-a4ce-99ce6649e79a" data-root-id="p1249" style="display: contents;"></div>

# %%
checkbox_group = CheckboxGroup(labels=["Option 1", "Option 2", "Option 3"], active=[0, 1])
show(checkbox_group)
# Out:
#   <div id="fdb7a0ed-1f1e-48b0-af23-fbddf84635c1" data-root-id="p1250" style="display: contents;"></div>

# %%
radio_group = RadioGroup(labels=["Option 1", "Option 2", "Option 3"], active=0)
show(radio_group)
# Out:
#   <div id="f0c85b34-cf67-481b-9d67-3a1f418b3209" data-root-id="p1251" style="display: contents;"></div>

# %%
#g. Employ Plotly to create a dropdown menu.
import plotly.graph_objects as go
fig = go.Figure()
fig.add_surface(z=df.values)
fig.update_layout(
    updatemenus=[
        dict(
            buttons=list([
                dict(
                    args=['type', 'surface'],
                    label='3D Surface',
                    method='restyle'
                ),
                dict(
                    args=['type', 'heatmap'],
                    label='Heatmap',
                    method='restyle'
                )
            ]),
            direction='down',
            showactive=True,
            x=0.1,
            xanchor='left',
            y=1.1,
            yanchor='top'
        ),
    ]
)
fig.show()
# Out:
# <div>                            <div id="57ec50b1-8b0f-4236-82b1-2dd1e910db6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57ec50b1-8b0f-4236-82b1-2dd1e910db6d")) {                    Plotly.newPlot(                        "57ec50b1-8b0f-4236-82b1-2dd1e910db6d",                        [{"z":[[6.0,148.0,72.0,35.0,0.0,33.6,0.627,50.0,1.0],[1.0,85.0,66.0,29.0,0.0,26.6,0.351,31.0,0.0],[8.0,183.0,64.0,0.0,0.0,23.3,0.672,32.0,1.0],[1.0,89.0,66.0,23.0,94.0,28.1,0.167,21.0,0.0],[0.0,137.0,40.0,35.0,168.0,43.1,2.288,33.0,1.0],[5.0,116.0,74.0,0.0,0.0,25.6,0.201,30.0,0.0],[3.0,78.0,50.0,32.0,88.0,31.0,0.248,26.0,1.0],[10.0,115.0,0.0,0.0,0.0,35.3,0.134,29.0,0.0],[2.0,197.0,70.0,45.0,543.0,30.5,0.158,53.0,1.0],[8.0,125.0,96.0,0.0,0.0,0.0,0.232,54.0,1.0],[4.
# ...

# %%
#h. Develop custom action buttons using Plotly
import plotly.graph_objects as go
import numpy as np
x = []
for i in "PREGNANCIES":
    x.append(i)
y = []
for j in "GLUCOSE":
    y.append(j)
color = np.random.rand(100)
fig = go.Figure()
fig.add_trace(go.Scatter(x=x, y=y, mode='markers', marker=dict(color=color)))
fig.update_layout(
    updatemenus=[
        dict(
            type="buttons",
            direction="right",
            buttons=[
                dict(
                    label="Change Color",
                    method="update",
                    args=[{"marker.color": np.random.rand(100)}],
                )
            ],
        )
    ]
)
fig.show()
# Out:
# <div>                            <div id="216f344a-abe8-4bf4-98d1-bd58b0e15b6e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("216f344a-abe8-4bf4-98d1-bd58b0e15b6e")) {                    Plotly.newPlot(                        "216f344a-abe8-4bf4-98d1-bd58b0e15b6e",                        [{"marker":{"color":[0.7046234361259265,0.9119077476176843,0.7268145227190062,0.7485555257335315,0.43374808441185486,0.8586993468085483,0.946047757925896,0.6390498140714842,0.7665701257877403,0.326583920925243,0.5594491352137819,0.9860690530584497,0.12099009164794405,0.250786935713295,0.7818189632214837,0.4531224678586513,0.4347054453871445,0.6530198328837887,0.38069669949222684,0.7759324542266663,0.24713273252904655,0.18235143737064552,0.6958801641035974,0.653220
# ...

# %% [markdown]
# ## DATA2

# %%
#a. Scatter plots with coloured points and adjustable sizes using columns (1) col1, col2 and (2) col3, col4 (3) col5, col6.
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_excel("C:\\Users\\NAMAN MAHESHWARI\\OneDrive\\Desktop\\FOURTH SEM\\ML\\LAB\\WEEK1\\Data2.xlsx")
df
# Out:
#     DISTCD          STATNAME            DISTNAME  BLOCKS  VILLAGES  CLUSTERS  \
# 0      101   JAMMU & KASHMIR             KUPWARA      13       391       104
# 1      102   JAMMU & KASHMIR            BARAMULA      18       678       144
# 2      103   JAMMU & KASHMIR            SRINAGAR       8        94        65
# 3      201  HIMACHAL PRADESH              CHAMBA      15      1150       266
# 4      202  HIMACHAL PRADESH              KANGRA      19      1785       358
# 5      203  HIMACHAL PRADESH       LAHUL & SPITI       4       168        53
# 6      309            PUNJAB            LUDHIANA      12      1044       143
# 7      310            PUNJAB                MOGA       5       332        46
# 8      311            PUNJAB            FIROZPUR       6       666        79
# 9      401        CHANDIGARH          CHANDIGARH      20        84        20
# 10     501       UTTARAKHAND          UTTARKASHI       6       662        61
# ...

# %%
#b. Line charts for columns (1) col1, col2 (2) col3, col4 (3) col5, col6.
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.lineplot(data=df, x='DISTCD', y='STATNAME')
plt.show()
sns.lineplot(data=df, x='DISTNAME', y='BLOCKS')
plt.show()
sns.lineplot(data=df, x='VILLAGES', y='CLUSTERS')
plt.show()

# %%
#c. Bar charts representing columns (1) col1, col2 (2) col3, col4 (3) col5, col6.
sns.barplot(data=df, x='DISTCD', y='STATNAME')
plt.show()
sns.barplot(data=df, x='DISTNAME', y='BLOCKS')
plt.show()
sns.barplot(data=df, x='VILLAGES', y='CLUSTERS')
plt.show()

# %%
#d. Histograms to depict the dataset's distribution.
df.drop("STATNAME",axis=1,inplace=True)
df.drop("DISTNAME",axis=1,inplace=True)
plt.hist(df)
plt.show()

# %%
#e. Employ Bokeh for interactive data visualization.
from bokeh.plotting import figure,show
from bokeh.io import output_notebook
c=figure(x_axis_label="BLOCKS",y_axis_label="VILLAGES")
c.vbar(x=df.BLOCKS,top=df.VILLAGES,width=0.8)
output_notebook()
show(c)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="cfc64876-f7e8-4c10-80c2-4c766f2aa84f">Loading BokehJS ...</span>
#     </div>
#   <div id="c53c012d-6232-472c-a2b1-157acb38386a" data-root-id="p1252" style="display: contents;"></div>

# %%
#f. Utilize Bokeh's GUI features, including buttons, sliders, checkboxes, and radio buttons.
from bokeh.models import Button,CheckboxGroup, RadioGroup, Slider
from bokeh.plotting import show

button = Button(label="Button")
show(button)
# Out:
#   <div id="f50a2803-e887-488e-9ff7-ca7402525802" data-root-id="p1291" style="display: contents;"></div>

# %%
slider = Slider(start=0, end=10, value=5, step=1, title="Slider")
show(slider)
# Out:
#   <div id="d4e9f53e-5c4f-4b69-95d1-01f1fa3ec8d6" data-root-id="p1292" style="display: contents;"></div>

# %%
checkbox_group = CheckboxGroup(labels=["Option 1", "Option 2", "Option 3"], active=[0, 1])
show(checkbox_group)
# Out:
#   <div id="c7fce17c-7a40-44e1-855a-2c7af5a21399" data-root-id="p1293" style="display: contents;"></div>

# %%
radio_group = RadioGroup(labels=["Option 1", "Option 2", "Option 3"], active=0)
show(radio_group)
# Out:
#   <div id="e4e9a469-9488-4d46-a065-52f482596f06" data-root-id="p1294" style="display: contents;"></div>

# %%
#g. Employ Plotly to create a dropdown menu.
import plotly.graph_objects as go
fig = go.Figure()
fig.add_surface(z=df.values)
fig.update_layout(
    updatemenus=[
        dict(
            buttons=list([
                dict(
                    args=['type', 'surface'],
                    label='3D Surface',
                    method='restyle'
                ),
                dict(
                    args=['type', 'heatmap'],
                    label='Heatmap',
                    method='restyle'
                )
            ]),
            direction='down',
            showactive=True,
            x=0.1,
            xanchor='left',
            y=1.1,
            yanchor='top'
        ),
    ]
)
fig.show()
# Out:
# <div>                            <div id="04258278-75a6-4b8e-9378-00f9704a829b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04258278-75a6-4b8e-9378-00f9704a829b")) {                    Plotly.newPlot(                        "04258278-75a6-4b8e-9378-00f9704a829b",                        [{"z":[[101,13,391,104,875564],[102,18,678,144,1015503],[103,8,94,65,1269751],[201,15,1150,266,518844],[202,19,1785,358,1507223],[203,4,168,53,31528],[309,12,1044,143,3487882],[310,5,332,46,992289],[311,6,666,79,2026831],[401,20,84,20,1054686],[501,6,662,61,329686],[502,9,809,78,391114],[503,3,537,46,236857],[601,4,279,43,558890],[602,6,431,75,1136784],[603,6,591,80,1214162],[701,9,224,9,3651261],[702,6,80,6,883418],[703,6,133,6,2240749],[801,9,1937,378,1969520],[
# ...
